# %%
from google.colab import drive
drive.mount('/content/pdrive')
# Out:
# Drive already mounted at /content/pdrive; to attempt to forcibly remount, call drive.mount("/content/pdrive", force_remount=True).

# %%
ROOT_DIR = '/content/pdrive/MyDrive/Final_Project/yolov8/'

# %%
# %cd {ROOT_DIR}
# Out:
# /content/pdrive/MyDrive/Final_Project/yolov8

# %%
# !git clone https://github.com/ultralytics/ultralytics.git
# Out:
# fatal: destination path 'ultralytics' already exists and is not an empty directory.

# %%
# %cd ultralytics
# Out:
# /content/pdrive/MyDrive/Final_Project/yolov8/ultralytics

# %%
# !pip install -r requirements.txt

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 614.9/614.9 kB 6.8 MB/s eta 0:00:00
# ...

# %%
# %cd {ROOT_DIR}
# Out:
# /content/pdrive/MyDrive/Final_Project/yolov8

# %%
from ultralytics import YOLO
import numpy as np
import cv2

# %% [markdown]
# ## Training on Custom dataset

# %%
# !pip install roboflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 kB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.3/59.3 kB 8.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.7 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=d1e688c4fd0c2efb813c98bd5270867af0a7ff0515dc32282a3e4e54e826af69
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.0
#     Uninstalling pyparsing-3.1.0:
#       Successfully uninstalled pyparsing-3.1.0
# ...

# %%
# from roboflow import Roboflow
# rf = Roboflow(api_key= "NkJ2URo6GWyildL2Fr3g")
# project = rf.workspace().project("numberplate")
#dataset = project.version(1).download("yolov8")

# %%
#{dataset.location}
dataset_loc = '/content/pdrive/MyDrive/Final_Project/yolov8/roboflow_dataset'

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8s.yaml")  # build a new model from scratch
# model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

# Use the model
# !yolo task=detect mode=train model=yolov8s.pt data={dataset_loc}/data.yaml epochs=20 imgsz=640
results = model.train(data=f"{dataset_loc}/data.yaml", epochs=20, imgsz=640)  # train the model
results = model.val()  # evaluate model performance on the validation set
results = model("input/images210.jpg")  # predict on an image
success = YOLO("yolov8n.pt").export(format="onnx")  # export a model to ONNX format
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
# ...
